# %% [markdown]
#  Ce projet a été réalisé par Namous Nassim, Khalid Makoudi et Addnane Ijjane dans le cadre d'un projet EDA (Exploratory Data Analysis) Dataset Netflix.

# %% [markdown]
# # I - Préparation des données

# %% [markdown]
# # Importation des bibliothèques requises
#
# **numpy:** Bibliothèque pour effectuer des opérations mathématiques sur les données
#
# **pandas:** Bibliothèque pour manipuler et analyser les données
#
# **matplotlib/seaborn:** Bibliothèque pour la visualisation des données

# %%
import    numpy   as       np
import    pandas     as        pd
import    matplotlib.pyplot   as   plt
import    seaborn

# %% [markdown]
# #  Chargement des données Netflix
#
# charger des données à partir d'un fichier CSV dans un DataFrame pandas

# %%
df  = pd.read_csv("netflix.csv") 
df
# Out:
#      show_id     type                  title         director
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# 0                                                   NaN  United States  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Les cinq premier données dans le dataframe

# %%
df.head()
# Out:
#   show_id     type                  title         director
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country
# 0                                                NaN  United States  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13     90 min  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
#  # Examiner le nombre de lignes et de colonnes dans l’ensemble de données.

# %%
df.shape
#  ligne : 8807 
#  colonnes : 12
# Out:
# (8807, 12)

# %% [markdown]
# # Afficher les noms des colonnes

# %%
 for     i    in     df.columns:
        print(i)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# rating
# duration
# listed_in
# description

# %% [markdown]
#  # Statistiques de base sur l’ensemble de données.

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# #  II - Nettoyage des données

# %% [markdown]
#  ***Créer un jeu de données df n’a que des colonnes (Relevant) à partir du jeu de données original***

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added
# 0       False  False  False     False   True    False       False  \
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64
